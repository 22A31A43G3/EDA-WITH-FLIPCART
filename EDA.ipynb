# %%
import pandas as pd
df=pd.read_csv("cleaned_wash_mac.csv",index_col=0)
df.head()
# Out:
#    ratings  discounts  prices      brand  energy_rating  capacity  \
# 0    24972         23   18790  Whirlpool              5       8.0
# 1    11841         39   15490  Panasonic              5       7.0
# 2    24972         24   14590  Whirlpool              5       7.0
# 3    22205         25   12890  Whirlpool              5       8.5
# 4    37103         19   11490         LG              5       7.0
#
#    max_spin_speed
# 0             740
# 1             700
# 2             740
# 3            1400
# 4            1350

# %%
df.describe()
# Out:
#             ratings   discounts        prices  energy_rating    capacity  \
# count    404.000000  404.000000    404.000000     404.000000  404.000000
# mean   13984.178218   28.655941  19247.071782       4.980198    8.011139
# std    21662.205415   10.165769   9753.335054       0.171416    1.447767
# min        3.000000    4.000000   6790.000000       3.000000    5.500000
# 25%      473.750000   23.000000  12536.500000       5.000000    7.000000
# 50%     3235.000000   27.000000  15999.000000       5.000000    8.000000
# 75%    20325.000000   34.000000  24540.000000       5.000000    9.000000
# max    84073.000000   60.000000  58990.000000       5.000000   14.000000
#
#        max_spin_speed
# count      404.000000
# mean      1089.594059
# std        309.000692
# min         55.000000
# 25%        740.000000
# 50%       1200.000000
# 75%       1400.000000
# max       1600.000000

# %%
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.1.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\vamsi\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
df.describe(include="O")
# Out:
#             brand
# count         404
# unique         24
# top     Whirlpool
# freq           63

# %%
df.brand.value_counts(normalize=True)
# Out:
# brand
# Whirlpool                                       0.155941
# LG                                              0.123762
# SAMSUNG                                         0.089109
# IFB                                             0.086634
# Godrej                                          0.081683
# Voltas Beko                                     0.074257
# Thomson                                         0.054455
# Haier                                           0.051980
# BOSCH                                           0.049505
# Panasonic                                       0.039604
# Lloyd                                           0.037129
# ONIDA                                           0.032178
# MarQ by Flipkart                                0.029703
# MOTOROLA                                        0.027228
# realme TechLife                                 0.024752
# Sansui                                          0.007426
# Acer                                            0.007426
# Singer                                          0.004950
# Midea                                           0.004950
# TCL                                             0.004950
# White Westinghouse (Trademark by Electrolux)    0.004950
# Electrolux                                      0.002475
# BLACK+DECKER                                    0.002475
# Siemens                                         0.002475
# Name: proportion, dtype: float64

# %%
df.brand.value_counts(normalize=True).plot(kind="bar")
# Out:
# <Axes: xlabel='brand'>

# %% [markdown]
# ### IN THE ABOVE PLOT WE CAN OBSERVE THE PROPORTION OF EACH BRAND BY THEIR FREQUENCY

# %%
sns.histplot(df.max_spin_speed)
# Out:
# <Axes: xlabel='max_spin_speed', ylabel='Count'>

# %% [markdown]
# ### THE ABOVE PLOT EXPLAINS THAT THERE IS MOST OF THE WASHING MACHINES IN DATA IN THE 1400 RPM

# %%
sns.histplot(df.discounts)
# Out:
# <Axes: xlabel='discounts', ylabel='Count'>

# %% [markdown]
# # THE DISCOUNTS COLUMN IS QUIET CLOSER TO NORMAL DISTRIBUTION WHICH IS VERY USEFUL FOR MODEL TRAINING

# %%
    sns.histplot(df.ratings)
# Out:
# <Axes: xlabel='ratings', ylabel='Count'>

# %% [markdown]
# # THE ABOVE PLOT SHOWS THAT THERE MIGHT BE OUTLIERS IN THE RATINGS COLUMN AND IT EXPLAINS US THERE IS MOST OF THE RATINGS UNDER 20000

# %%
sns.boxplot(df.ratings)
# Out:
# <Axes: ylabel='ratings'>

# %% [markdown]
# # THE ABOVE BOXPLOT SHOWS THAT THE RATINGS COLUMN SEEMS DESCENT

# %%
(df.ratings>45000).sum()
# Out:
# np.int64(40)

# %%
sns.violinplot(df[["prices","ratings"]])
# Out:
# <Axes: >

# %%
sns.histplot(df.groupby("brand")["prices"].mean())
# Out:
# <Axes: xlabel='prices', ylabel='Count'>

# %% [markdown]
# # BY ABOVE PLOT WE CAN UNDERSTAND THAT THE AVERAGE PRICES OF THE MOST OF BRANDS LIES BETWEEN 10-20K

# %%
pd.pivot_table(df,columns="brand",values="discounts",aggfunc="mean")
# Out:
# brand           Acer  BLACK+DECKER  BOSCH  Electrolux     Godrej      Haier  \
# discounts  50.666667          34.0  30.15        53.0  33.424242  35.190476
#
# brand       IFB     LG      Lloyd   MOTOROLA  ...  SAMSUNG  Sansui  Siemens  \
# discounts  22.6  23.48  29.333333  43.454545  ...     19.5    34.0     23.0
#
# brand      Singer   TCL    Thomson  Voltas Beko  Whirlpool  \
# discounts    38.0  41.0  27.136364         36.8   22.84127
#
# brand      White Westinghouse (Trademark by Electrolux)  realme TechLife
# discounts                                          32.0             45.8
#
# [1 rows x 24 columns]

# %%
df.select_dtypes(exclude="O").corrwith(df["discounts"])
# Out:
# ratings          -0.119287
# discounts         1.000000
# prices           -0.194931
# energy_rating     0.124238
# capacity          0.058259
# max_spin_speed    0.011875
# dtype: float64

# %% [markdown]
# # WE CAN OBSERVE THAT DISCOUNTS HAVE SOME LITTLE CORRELATION WITH PRICE

# %%
plt.scatter(df.discounts,df.prices)
plt.xlabel("discounts")
plt.ylabel("prices")
# Out:
# Text(0, 0.5, 'prices')

# %% [markdown]
# # AS WE OBSERVED BEFORE THE WASHING MACHINES PEICES ARE AROUND 10-20K DUE TO THE HUGE DICOUNTS OF 20-30%

# %%
sns.scatterplot(x=df.discounts,y=df.prices,hue=df.prices)
# Out:
# <Axes: xlabel='discounts', ylabel='prices'>

# %%
df.select_dtypes(exclude="O").corrwith(df["prices"])
# Out:
# ratings           0.109083
# discounts        -0.194931
# prices            1.000000
# energy_rating     0.030833
# capacity          0.195070
# max_spin_speed   -0.060104
# dtype: float64

# %% [markdown]
# # BY THE ABOVE CORRELATIONS WE CAN OBSEVRE THERE IS VERY LESS CORRELATION AMONG THE FEATURES WITH THE PRICE TARGET FEATURE BUT [RATINGS,DISCOUNTS,CAPACITY] HAVE A LITTLE CORRELATION WITH PRICES COMPARING WITH OTHER FEATURES

# %%
df.select_dtypes(exclude="O").corr()
# Out:
#                  ratings  discounts    prices  energy_rating  capacity  \
# ratings         1.000000  -0.119287  0.109083      -0.062585 -0.038558
# discounts      -0.119287   1.000000 -0.194931       0.124238  0.058259
# prices          0.109083  -0.194931  1.000000       0.030833  0.195070
# energy_rating  -0.062585   0.124238  0.030833       1.000000  0.120875
# capacity       -0.038558   0.058259  0.195070       0.120875  1.000000
# max_spin_speed -0.013278   0.011875 -0.060104       0.129146  0.186286
#
#                 max_spin_speed
# ratings              -0.013278
# discounts             0.011875
# prices               -0.060104
# energy_rating         0.129146
# capacity              0.186286
# max_spin_speed        1.000000

# %% [markdown]
# # CONCLUSION:WE CANNOT FIND ANY BETTER CORRELATION AMONG THE FEATURES BUT ITS BETTER TO BUILD MODEL BEFORE TAKING DECISON WITH FEATURES HAVING A LITTLE CORRELATION WE OBSERVED THAT MOST OF THE PRICES ARE AROUND 10-20K WHICH IS DUE TO THE DISCOUNTS FOR 20-30% AND ALSO THERE IS LITTLE MULTICOLINIARITY AMONG FEW FEATURES
